# %%
from negativeHarmonizer import Negator, ReHarmonizer

# %% [markdown]
# ## Example of The Negator Module Generarting a Negative CounterPart by Pitch
#     - takes in a key and the midi note to be converted

# %%
Converter = Negator(key='C')
Converter.convert(midi_n=60)
# Out:
# 67

# %%
Converter = Negator(key='C#')
Converter.convert(midi_n=60)
# Out:
# 69

# %%
Converter = Negator(key='Db')
Converter.convert(midi_n=60)
# Out:
# 69

# %%
Converter = Negator(key='D')
Converter.convert(midi_n=60)
# Out:
# 71

# %% [markdown]
# ## Example of the ReHarmonizer
#      - Takes in a midi file
#      - outputs a negative of the midi file

# %%
MID = 'deb_clai.mid'
outMid = 'NEGATIVE_DEB'

ReHarmonizer(Inf=MID, Outf=outMid)
# Out:
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 80 -> 73
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 77 -> 76
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 77 -> 76
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 80 -> 73
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 77 -> 76
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 73 -> 80
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 73 -> 80
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 77 -> 76
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 72 -> 81
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 75 -> 78
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 75 -> 78
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 72 -> 81
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 73 -> 80
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 77 -> 76
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 77 -> 76
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 73 -> 80
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 75 -> 78
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 72 -> 81
# 2021-07-15 19:45:58 [INFO] NegHarm-Log - 72 -> 81
# ...
